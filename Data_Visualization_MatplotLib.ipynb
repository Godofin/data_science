# %% [markdown]
# <a href="https://colab.research.google.com/github/Godofin/data_science/blob/main/Data_Visualization_MatplotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Aula1
#
# Fazendo as primeiras visualizações

# %%
import pandas as pd #importando o pandas

# %%
df = pd.read_csv("monitoramento_tempo.csv") #Lendo os dados em CSV
df.head() #Cabeçalho dos dados
# Out:
#    temperatura  pressão  ...  dia_da_semana                 data
# 0   282.080000   1024.0  ...        Domingo  2012-10-01 12:00:00
# 1   282.080000   1024.0  ...        Domingo  2012-10-01 13:00:00
# 2   282.083252   1024.0  ...        Domingo  2012-10-01 14:00:00
# 3   282.091866   1024.0  ...        Domingo  2012-10-01 15:00:00
# 4   282.100481   1024.0  ...        Domingo  2012-10-01 16:00:00
#
# [5 rows x 7 columns]

# %%
df.info() #expondo as informações dos dados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
df['data'] = pd.to_datetime(df['data']) #convertendo a coluna data para estilo de dados tipo data

# %%
import matplotlib.pyplot as plt #Importando o matplot #Deixando os dados automáticos
# %matplotlib inline

# %%
plt.plot(df['data'], df['temperatura']) #Plotando um gráfico linha com eixo X=data e eixo Y=Temperatura

# %%
plt.figure(figsize=(15,8))              #Mudando as dimensões do gráfico por horizontal e vertical
plt.plot(df['data'], df['temperatura']) #Plotando um gráfico linha com eixo X=data e eixo Y=Temperatura

# %%
plt.figure(figsize=(15,8))              #Mudando as dimensões do gráfico por horizontal e vertical
plt.plot(df['data'], df['temperatura']) #Plotando um gráfico linha com eixo X=data e eixo Y=Temperatura
plt.title('Temperatura no tempo')       #Colocando um título no gráfico
# Out:
# Text(0.5, 1.0, 'Temperatura no tempo')

# %%
fig = plt.figure(figsize=(15,8)) #Objeto de figura
eixo = fig.add_axes([0, 0, 1, 1]) #Definindo os eixos de 0 à 1

# %%
fig = plt.figure(figsize=(15,8)) #Objeto de figura
eixo = fig.add_axes([0, 0, 1, 1]) #Definindo os eixos de 0 à 1
eixo.plot(df['data'], df['temperatura']) #definindo o que colocar em cada eixo
eixo.set_title('temperatura no momento') #Título do gráfico
# Out:
# Text(0.5, 1.0, 'temperatura no momento')

# %%
fig = plt.figure(figsize=(15,8)) #Objeto de figura
eixo = fig.add_axes([0, 0, 1, 1]) #Definindo os eixos de 0 à 1
eixo.plot(df['data'], df['temperatura']) #definindo o que colocar em cada eixo
eixo.set_title('temperatura no momento') #Título do gráfico
eixo.set_ylabel('Temperatura')  #Define legenda no eixo Y
eixo.set_xlabel('Data')  #Define legenda no eixo X
# Out:
# Text(0.5, 0, 'Data')

# %%
fig = plt.figure(figsize=(15,8)) #Objeto de figura
eixo = fig.add_axes([0, 0, 1, 1]) #Definindo os eixos de 0 à 1
eixo.plot(df['data'], df['temperatura']) #definindo o que colocar em cada eixo
eixo.set_title('Temperatura no momento', fontsize=25) #Título do gráfico e tamanho da fonte
eixo.set_ylabel('Temperatura', fontsize=15)  #Define legenda no eixo Y e tamanho da fonte
eixo.set_xlabel('Data', fontsize=15)  #Define legenda no eixo X e tamanho da fonte
# Out:
# Text(0.5, 0, 'Data')

# %%
fig = plt.figure(figsize=(15,8)) #Objeto de figura
eixo = fig.add_axes([0, 0, 1, 1]) #Definindo os eixos de 0 à 1
eixo.plot(df['data'], df['temperatura']) #definindo o que colocar em cada eixo
eixo.set_title('Temperatura no momento', fontsize=25) #Título do gráfico e tamanho da fonte
eixo.set_ylabel('Temperatura', fontsize=15)  #Define legenda no eixo Y e tamanho da fonte
eixo.set_xlabel('Data', fontsize=15)  #Define legenda no eixo X e tamanho da fonte
eixo.legend(['Temperatura'], loc='lower right', fontsize=15) #Colocando a legenda do gráfico

# %%
fig = plt.figure(figsize=(15,8)) #Objeto de figura
eixo = fig.add_axes([0, 0, 1, 1]) #Definindo os eixos de 0 à 1
eixo.plot(df['data'], df['temperatura'], color='green') #definindo o que colocar em cada eixo e mudando a cor

eixo.set_title('Temperatura no momento', fontsize=25) #Título do gráfico e tamanho da fonte
eixo.set_ylabel('Temperatura', fontsize=15)  #Define legenda no eixo Y e tamanho da fonte
eixo.set_xlabel('Data', fontsize=15)  #Define legenda no eixo X e tamanho da fonte
eixo.legend(['Temperatura'], loc='lower right', fontsize=15) #Colocando a legenda do gráfico

# %% [markdown]
# #Aula 2
#
# Customizando nossas visualizações

# %%
fig = plt.figure(figsize=(15,8)) #Objeto de figura
eixo = fig.add_axes([0, 0, 1, 1]) #Definindo os eixos de 0 à 1
eixo.plot(df['data'], df['temperatura'], color='g', lw = 4) #definindo o que colocar em cada eixo e mudando a cor, lw muda a expessura da linha

eixo.set_title('Temperatura no momento', fontsize=25) #Título do gráfico e tamanho da fonte
eixo.set_ylabel('Temperatura', fontsize=15)  #Define legenda no eixo Y e tamanho da fonte
eixo.set_xlabel('Data', fontsize=15)  #Define legenda no eixo X e tamanho da fonte
eixo.legend(['Temperatura'], loc='lower right', fontsize=15) #Colocando a legenda do gráfico

# %%
fig = plt.figure(figsize=(15,8)) #Objeto de figura
eixo = fig.add_axes([0, 0, 1, 1]) #Definindo os eixos de 0 à 1
eixo.plot(df['data'], df['temperatura'], color='g', lw = 0.4) #definindo o que colocar em cada eixo e mudando a cor, lw muda a expessura da linha

eixo.set_title('Temperatura no momento', fontsize=25) #Título do gráfico e tamanho da fonte
eixo.set_ylabel('Temperatura', fontsize=15)  #Define legenda no eixo Y e tamanho da fonte
eixo.set_xlabel('Data', fontsize=15)  #Define legenda no eixo X e tamanho da fonte
eixo.legend(['Temperatura'], loc='lower right', fontsize=15) #Colocando a legenda do gráfico

# %%
fig = plt.figure(figsize=(15,8)) #Objeto de figura
eixo = fig.add_axes([0, 0, 1, 1]) #Definindo os eixos de 0 à 1
eixo.plot(df['data'], df['temperatura'], color='g', ls = "dotted") #definindo o que colocar em cada eixo e mudando a cor, lw muda a expessura da linha
#ls = line style,
eixo.set_title('Temperatura no momento', fontsize=25) #Título do gráfico e tamanho da fonte
eixo.set_ylabel('Temperatura', fontsize=15)  #Define legenda no eixo Y e tamanho da fonte
eixo.set_xlabel('Data', fontsize=15)  #Define legenda no eixo X e tamanho da fonte
eixo.legend(['Temperatura'], loc='lower right', fontsize=15) #Colocando a legenda do gráfico

# %%
import datetime

# %%
fig = plt.figure(figsize=(15,8)) #Objeto de figura
eixo = fig.add_axes([0, 0, 1, 1]) #Definindo os eixos de 0 à 1
eixo.plot(df['data'], df['temperatura'], color='g') #definindo o que colocar em cada eixo e mudando a cor, lw muda a expessura da linha
#
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1)) # limitando as datas
eixo.set_title('Temperatura no momento', fontsize=25) #Título do gráfico e tamanho da fonte
eixo.set_ylabel('Temperatura', fontsize=15)  #Define legenda no eixo Y e tamanho da fonte
eixo.set_xlabel('Data', fontsize=15)  #Define legenda no eixo X e tamanho da fonte
eixo.legend(['Temperatura'], loc='lower right', fontsize=15) #Colocando a legenda do gráfico

# %%
fig = plt.figure(figsize=(15,8)) #Objeto de figura
eixo = fig.add_axes([0, 0, 1, 1]) #Definindo os eixos de 0 à 1
eixo.plot(df['data'], df['temperatura'], color='g', marker = "o") #definindo o que colocar em cada eixo e mudando a cor, lw muda a expessura da linha
#
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1)) # limitando as datas
eixo.set_title('Temperatura no momento', fontsize=25) #Título do gráfico e tamanho da fonte
eixo.set_ylabel('Temperatura', fontsize=15)  #Define legenda no eixo Y e tamanho da fonte
eixo.set_xlabel('Data', fontsize=15)  #Define legenda no eixo X e tamanho da fonte
eixo.legend(['Temperatura'], loc='lower right', fontsize=15) #Colocando a legenda do gráfico

# %%
fig = plt.figure(figsize=(15,8)) #Objeto de figura
eixo = fig.add_axes([0, 0, 1, 1]) #Definindo os eixos de 0 à 1
eixo.plot(df['data'], df['temperatura'], color='g') #definindo o que colocar em cada eixo e mudando a cor, lw muda a expessura da linha
#
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1)) # limitando as datas
eixo.set_title('Temperatura no momento', fontsize=25) #Título do gráfico e tamanho da fonte
eixo.set_ylabel('Temperatura', fontsize=15)  #Define legenda no eixo Y e tamanho da fonte
eixo.set_xlabel('Data', fontsize=15)  #Define legenda no eixo X e tamanho da fonte
eixo.legend(['Temperatura'], loc='lower right', fontsize=15) #Colocando a legenda do gráfico
eixo.grid(True) #Plota a grade no gráfico

# %%
fig= plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.1,0.5,0.4,0.4])

# %%
fig= plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.1,0.5,0.4,0.4])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color='g')
eixo.set_title('Temperatura no momento', fontsize = 25, pad=20)
eixo.legend(['temperatura'], loc = 'best', fontsize=10)
eixo.set_ylabel('Temperatura', fontsize=15)  
eixo.set_xlabel('Data', fontsize=15)

eixo2.plot(df['data'], df['temperatura'], color='b')
eixo2.set_title('Temperatura no momento', fontsize = 15)
eixo2.legend(['temperatura'], loc = 'best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)  
eixo2.set_xlabel('Data', fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %%
fig= plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.7,0.65,0.3,0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color='g')
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1)) # limitando as datas
eixo.set_title('Temperatura em 2014', fontsize = 25, pad=20)
eixo.legend(['temperatura'], loc = 'lower right', fontsize=10)
eixo.set_ylabel('Temperatura', fontsize=15)  
eixo.set_xlabel('Data', fontsize=15)

eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color='b')
eixo2.set_title('Temperatura no momento', fontsize = 15)
eixo2.legend(['temperatura'], loc = 'best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)  
eixo2.set_xlabel('Data', fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %%
fig= plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.7,0.65,0.3,0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color='g')
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1)) # limitando as datas
eixo.set_ylim(271, 320)
eixo.set_title('Temperatura em maio de 2014', fontsize = 25, pad=20)
eixo.legend(['temperatura'], loc = 'lower right', fontsize=10)
eixo.set_ylabel('Temperatura', fontsize=15)  
eixo.set_xlabel('Data', fontsize=15)

eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color='g')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014', fontsize = 15)
eixo2.legend(['temperatura'], loc = 'best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)  
eixo2.set_xlabel('Data', fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %%
fig= plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.7,0.65,0.3,0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color='g')
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1)) # limitando as datas
eixo.set_ylim(271, 320)
eixo.set_title('Temperatura em maio de 2014', fontsize = 25, pad=20)
eixo.legend(['temperatura'], loc = 'lower right', fontsize=10)
eixo.set_ylabel('Temperatura', fontsize=15)  
eixo.set_xlabel('Data', fontsize=15)

azul_esquerd = df['data'] < datetime.datetime(2014,5,1)
azul_direita = df['data'] > datetime.datetime(2014,6,1)

eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color='g')
eixo2.plot(df[azul_esquerd]['data'], df[azul_esquerd]['temperatura'], color='b')
eixo2.plot(df[azul_direita]['data'], df[azul_direita]['temperatura'], color='b')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014', fontsize = 15)
eixo2.legend(['temperatura'], loc = 'best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)  
eixo2.set_xlabel('Data', fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# #Aula 3

# %%
fig = plt.figure(figsize =(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.set_title('Temperatura no momento', fontsize = 25, pad=20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend(['Temperatura'], loc= 'lower right', fontsize = 15)
eixo.grid(True)

eixo.axhline(max(df['temperatura']), color = 'k', linestyle='--') #Cria o ponto máximo do gráfico
eixo.axhline(min(df['temperatura']), color = 'k', linestyle='--') #Cria o ponto mínimo do gráfico

# %%
fig = plt.figure(figsize =(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.set_title('Temperatura no momento', fontsize = 25, pad=20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend(['Temperatura'], loc= 'lower right', fontsize = 15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()] #Cria a localização para a anotação
y1 = max(df['temperatura'])

eixo.annotate('Máximo', xy = (x1, y1), fontsize= 15) #Cria a anotação de máximo

eixo.axhline(max(df['temperatura']), color = 'r', linestyle='--') #Cria o ponto máximo do gráfico
eixo.axhline(min(df['temperatura']), color = 'r', linestyle='--') #Cria o ponto mínimo do gráfico

# %%
fig = plt.figure(figsize =(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.set_title('Temperatura no momento', fontsize = 25, pad=20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend(['Temperatura'], loc= 'lower right', fontsize = 15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()] #Cria a localização para a anotação
y1 = max(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmax() - 7000]
y2 = max(df['temperatura'] - 5)

eixo.annotate('Mínimo', xy = (x1, y1), fontsize= 15, #Cria a anotação de máximo
              xytext = (x2,y2), arrowprops=dict(facecolor='k')) # cria a seta e aponta para o lugar certo

x1 = df['data'][df['temperatura'].idxmin()] #Cria a localização para a anotação
y1 = min(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmin() - 7000]
y2 = min(df['temperatura'] + 5)

eixo.annotate('Máximo', xy = (x1, y1), fontsize= 15, #Cria a anotação de máximo
              xytext = (x2,y2), arrowprops=dict(facecolor='k')) # cria a seta e aponta para o lugar certo

eixo.axhline(max(df['temperatura']), color = 'r', linestyle='--') #Cria o ponto máximo do gráfico
eixo.axhline(min(df['temperatura']), color = 'r', linestyle='--') #Cria o ponto mínimo do gráfico

# %%
temperatura_por_dia_da_semana =  df.groupby('dia_da_semana')['temperatura'].mean()
nome_dias = ['Domingo', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado']
temperatura_por_dia_da_semana = temperatura_por_dia_da_semana[nome_dias]
temperatura_por_dia_da_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Segunda    284.985382
# Terça      284.892811
# Quarta     284.998290
# Quinta     285.000643
# Sexta      285.060886
# Sábado     285.003316
# Name: temperatura, dtype: float64

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))

eixo.bar(indice, temperatura_por_dia_da_semana)
eixo.set_title('Temperatura por dia da semana', fontsize = 20, pad = 10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura Média', fontsize=15)
# Out:
# Text(0, 0.5, 'Temperatura Média')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))

eixo.bar(indice, temperatura_por_dia_da_semana)
eixo.set_title('Temperatura por dia da semana', fontsize = 20, pad = 10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura Média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))
cores = ['black', 'r', 'g', 'b', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color=cores)
eixo.set_title('Temperatura por dia da semana', fontsize = 20, pad = 10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura Média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))
cores = ['black', 'r', 'g', 'b', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color=cores, edgecolor = 'k')
eixo.set_title('Temperatura por dia da semana', fontsize = 20, pad = 10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura Média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.pie(temperatura_por_dia_da_semana, labels=temperatura_por_dia_da_semana.index)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=15)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.pie(temperatura_por_dia_da_semana, labels=temperatura_por_dia_da_semana.index,
         autopct = '%.1f%%')

eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=15)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

explodir = [0.1,0,0,0,0,0.1,0.1]

eixo.pie(temperatura_por_dia_da_semana, labels=temperatura_por_dia_da_semana.index,
         autopct = '%.1f%%', explode=explodir, shadow=True)

eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=15)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %% [markdown]
# #Aula 4
#
# íris

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    comprimento_sépala  largura_sépala  ...  largura_pétala      espécie
# 0                 5.1             3.5  ...             0.2  Iris-setosa
# 1                 4.9             3.0  ...             0.2  Iris-setosa
# 2                 4.7             3.2  ...             0.2  Iris-setosa
# 3                 4.6             3.1  ...             0.2  Iris-setosa
# 4                 5.0             3.6  ...             0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   comprimento_sépala  150 non-null    float64
#  1   largura_sépala      150 non-null    float64
#  2   comprimento_pétala  150 non-null    float64
#  3   largura_pétala      150 non-null    float64
#  4   espécie             150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(df['comprimento_sépala'], df['largura_sépala'])
eixo.set_title("Gráfico de dispersão da sépala", fontsize=25, pad=15)
eixo.set_xlabel("Comprimento", fontsize = 15)
eixo.set_ylabel("Largura", fontsize = 15)
# Out:
# Text(0, 0.5, 'Largura')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(df['comprimento_sépala'], df['largura_sépala'])
eixo.set_title("Gráfico de dispersão da sépala", fontsize=25, pad=15)
eixo.set_xlabel("Comprimento", fontsize = 15)
eixo.set_ylabel("Largura", fontsize = 15)
eixo.tick_params(labelsize = 15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'r', 'Iris-versicolor':'b', 'Iris-virginica':'g'}

for especie in df['espécie'].unique():
  tmp = df[df['espécie'] == especie]
  eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
                    color =cores[especie] )


eixo.set_title("Gráfico de dispersão da sépala", fontsize=25, pad=15)
eixo.set_xlabel("Comprimento", fontsize = 15)
eixo.set_ylabel("Largura", fontsize = 15)
eixo.tick_params(labelsize = 15)
eixo.legend(cores, fontsize=20)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'r', 'Iris-versicolor':'b', 'Iris-virginica':'g'}
marcadores = {'Iris-setosa':'x', 'Iris-versicolor':'o', 'Iris-virginica':'v'}

for especie in df['espécie'].unique():
  tmp = df[df['espécie'] == especie]
  eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
                    color =cores[especie], marker=marcadores[especie] )


eixo.set_title("Gráfico de dispersão da sépala", fontsize=25, pad=15)
eixo.set_xlabel("Comprimento", fontsize = 15)
eixo.set_ylabel("Largura", fontsize = 15)
eixo.tick_params(labelsize = 15)
eixo.legend(cores, fontsize=20)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'r', 'Iris-versicolor':'b', 'Iris-virginica':'g'}
marcadores = {'Iris-setosa':'x', 'Iris-versicolor':'o', 'Iris-virginica':'v'}

for especie in df['espécie'].unique():
  tmp = df[df['espécie'] == especie]
  
  eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
              color =cores[especie], marker=marcadores[especie],
              s=100)


eixo.set_title("Gráfico de dispersão da sépala", fontsize=25, pad=15)
eixo.set_xlabel("Comprimento", fontsize = 15)
eixo.set_ylabel("Largura", fontsize = 15)
eixo.tick_params(labelsize = 15)
eixo.legend(cores, fontsize=20)

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(df['largura_pétala'])
eixo.set_title("Gráfico de caixa", fontsize=15, pad=10)
eixo.set_xticklabels(['largura_pétala'])
# Out:
# [Text(0, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(df.drop('espécie', axis=1).values)
eixo.set_title("Gráfico de caixa", fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1).columns)
# Out:
# [Text(0, 0, 'comprimento_sépala'),
#  Text(0, 0, 'largura_sépala'),
#  Text(0, 0, 'comprimento_pétala'),
#  Text(0, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(df.drop('espécie', axis=1).values, patch_artist=True)
eixo.set_title("Gráfico de caixa", fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1).columns)
# Out:
# [Text(0, 0, 'comprimento_sépala'),
#  Text(0, 0, 'largura_sépala'),
#  Text(0, 0, 'comprimento_pétala'),
#  Text(0, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

cores=['red', 'blue', 'orange', 'green']

caixas = eixo.boxplot(df.drop('espécie', axis=1).values, patch_artist=True)
eixo.set_title("Gráfico de caixa", fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1).columns)

for caixa, cor in zip(caixas['boxes'], cores):
  caixa.set(color=cor)

caixas
# Out:
# {'boxes': [<matplotlib.patches.PathPatch at 0x7f1bbdd6b0b8>,
#   <matplotlib.patches.PathPatch at 0x7f1bbdc66518>,
#   <matplotlib.patches.PathPatch at 0x7f1bbe95fe10>,
#   <matplotlib.patches.PathPatch at 0x7f1bbd9e8128>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1bbdd6beb8>,
#   <matplotlib.lines.Line2D at 0x7f1bbdd71748>,
#   <matplotlib.lines.Line2D at 0x7f1bbdb3e6d8>,
#   <matplotlib.lines.Line2D at 0x7f1bbdb38fd0>,
#   <matplotlib.lines.Line2D at 0x7f1bbd9dc080>,
#   <matplotlib.lines.Line2D at 0x7f1bbd9dc400>,
#   <matplotlib.lines.Line2D at 0x7f1bbd9e8860>,
#   <matplotlib.lines.Line2D at 0x7f1bbd9e8be0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1bbddf6d30>,
#   <matplotlib.lines.Line2D at 0x7f1bbdb49198>,
#   <matplotlib.lines.Line2D at 0x7f1bbd9dcb00>,
#   <matplotlib.lines.Line2D at 0x7f1bbd9f1320>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1bbdd71e48>,
#   <matplotlib.lines.Line2D at 0x7f1bbdb38da0>,
#   <matplotlib.lines.Line2D at 0x7f1bbd9dc780>,
#   <matplotlib.lines.Line2D at 0x7f1bbd9e8f60>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1bbdd6b518>,
#   <matplotlib.lines.Line2D at 0x7f1bbdd6b908>,
#   <matplotlib.lines.Line2D at 0x7f1bbdc17198>,
#   <matplotlib.lines.Line2D at 0x7f1bbdb53f98>,
#   <matplotlib.lines.Line2D at 0x7f1bbe95f0f0>,
#   <matplotlib.lines.Line2D at 0x7f1bbe95f9e8>,
#   <matplotlib.lines.Line2D at 0x7f1bbd9e83c8>,
#   <matplotlib.lines.Line2D at 0x7f1bbd9e84e0>]}

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

cores=['red', 'blue', 'orange', 'green']


caixas = eixo.boxplot(df.drop('espécie', axis=1).values, patch_artist=True)
eixo.set_title("Gráfico de caixa", fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1).columns)
eixo.grid(True)

for caixa, cor in zip(caixas['boxes'], cores):
  caixa.set(color=cor)

for outlier in caixas['fliers']:
  outlier.set(marker='x', markersize=8)

caixas
# Out:
# {'boxes': [<matplotlib.patches.PathPatch at 0x7f1bbd8f4dd8>,
#   <matplotlib.patches.PathPatch at 0x7f1bbd913588>,
#   <matplotlib.patches.PathPatch at 0x7f1bbd8bdcf8>,
#   <matplotlib.patches.PathPatch at 0x7f1bbd8c1588>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1bbd8fb518>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8fb898>,
#   <matplotlib.lines.Line2D at 0x7f1bbd913cc0>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8bd080>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8a74e0>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8a7860>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8c1cc0>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8ca080>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1bbd8def60>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8bd780>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8a7f60>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8ca780>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1bbd8fbc18>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8bd400>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8a7be0>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8ca400>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1bbd8fb048>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8fb198>,
#   <matplotlib.lines.Line2D at 0x7f1bbd913828>,
#   <matplotlib.lines.Line2D at 0x7f1bbd913940>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8bdfd0>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8a7160>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8c1828>,
#   <matplotlib.lines.Line2D at 0x7f1bbd8c1940>]}

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df['comprimento_pétala'])
eixo.set_title("Histograma", fontsize=15, pad=10)
eixo.set_xlabel("Comprimento da pétala", fontsize=15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df['comprimento_pétala'], bins=20)
eixo.set_title("Histograma", fontsize=15, pad=10)
eixo.set_xlabel("Comprimento da pétala", fontsize=15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df['comprimento_pétala'], bins=20, orientation='vertical', density=True)
eixo.set_title("Histograma", fontsize=15, pad=10)
eixo.set_xlabel("Comprimento da pétala", fontsize=15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df['comprimento_pétala'], bins=20, orientation='vertical')
eixo.set_title("Histograma", fontsize=15, pad=10)
eixo.set_xlabel("Comprimento da pétala", fontsize=15)
eixo.grid(True)
eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma),
                xy=(4.5, 20), fontsize=20)
# Out:
# Text(4.5, 20, '$mu = 3.76$\n$sigma = 1.76$')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df['comprimento_pétala'], bins=20, orientation='vertical')
eixo.set_title("Histograma", fontsize=15, pad=10)
eixo.set_xlabel("Comprimento da pétala", fontsize=15)
eixo.grid(True)
eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma),
                xy=(4.5, 20), fontsize=20)

eixo.axvline(mu, color='k', linestyle='--')
eixo.annotate('média', xy=(mu-1.3, 28), fontsize=20)
# Out:
# Text(2.4586666666666694, 28, 'média')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df['comprimento_pétala'], bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
               xy=(4.5, 20), fontsize=20)

eixo.axvline(mu, color = 'k', linestyle='--')
eixo.annotate('média', xy=(mu-1.3, 28), fontsize=20)

eixo.axvline(df['comprimento_pétala'].median(), color='g', linestyle='--')
eixo.annotate('mediana', xy=(df['comprimento_pétala'].median(), 31), fontsize=20)
# Out:
# Text(4.35, 31, 'mediana')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

df_iv = df[df['espécie'] == 'Iris-versicolor']

mu, sigma = df_iv['comprimento_pétala'].mean(), df_iv['comprimento_pétala'].std()

eixo.hist(df_iv['comprimento_pétala'], bins=20)
eixo.set_title('Iris Versicolor', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
               xy=(4.6, 6), fontsize=20)

eixo.axvline(mu, color = 'k', linestyle='--')
eixo.annotate('média', xy=(mu-0.5, 5.5), fontsize=20)

eixo.axvline(df_iv['comprimento_pétala'].median(), color='g', linestyle='--')
eixo.annotate('mediana', xy=(df_iv['comprimento_pétala'].median()-0.7, 6.5), fontsize=20,
               color='g')
# Out:
# Text(3.6499999999999995, 6.5, 'mediana')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

df_is = df[df['espécie'] == 'Iris-setosa']

mu, sigma = df_is['comprimento_pétala'].mean(), df_is['comprimento_pétala'].std()

eixo.hist(df_is['comprimento_pétala'], bins=20)
eixo.set_title('Iris Setosa', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
               xy=(1.7, 7), fontsize=20)

eixo.axvline(mu, color = 'k', linestyle='--')
eixo.annotate('média', xy=(mu-0.2, 13.5), fontsize=20)

eixo.axvline(df_is['comprimento_pétala'].median(), color='g', linestyle='--')
eixo.annotate('mediana', xy=(df_is['comprimento_pétala'].median()+0.05, 12), fontsize=20,
               color='g')

fig.savefig('histograma_is.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

df_ivc = df[df['espécie'] == 'Iris-virginica']

mu, sigma = df_ivc['comprimento_pétala'].mean(), df_ivc['comprimento_pétala'].std()

eixo.hist(df_ivc['comprimento_pétala'], bins=20)
eixo.set_title('Iris Virginca', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
               xy=(6.3, 7), fontsize=20)

eixo.axvline(mu, color = 'k', linestyle='--')
eixo.annotate('média', xy=(mu, 8), fontsize=20)

eixo.axvline(df_ivc['comprimento_pétala'].median(), color='g', linestyle='--')
eixo.annotate('mediana', xy=(df_ivc['comprimento_pétala'].median(), 7), fontsize=20,
               color='g')

fig.savefig('histograma_ivg.png', bbox_inches='tight')

# %%
from PIL import Image

largura, altura = Image.open('histograma_ivg.png').size
combinada = Image.new("RGB", (3*largura, altura))
intervalo = 0
for imagem in map(Image.open, ['histograma_iv.png', 'histograma_is.png',
                               'histograma_ivg.png']):
    combinada.paste(imagem, (intervalo, 0))
    intervalo += largura

combinada.save('combinada.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-83-bf936adf73da> in <module>()
#       5 intervalo = 0
#       6 for imagem in map(Image.open, ['histograma_iv.png', 'histograma_is.png',
# ----> 7                                'histograma_ivg.png']):
#       8     combinada.paste(imagem, (intervalo, 0))
#       9     intervalo += largura
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'histograma_iv.png'

# %%
combinada
# Out:
# <PIL.Image.Image image mode=RGB size=1176x361 at 0x7F1BBD5DFAC8>
